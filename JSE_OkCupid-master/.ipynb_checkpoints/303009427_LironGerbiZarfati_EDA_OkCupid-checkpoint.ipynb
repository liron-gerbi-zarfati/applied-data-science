# %% [markdown]
# # JSE_OkCupid Project

# %% [markdown]
# ## The imports

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Data

# %%
df=pd.read_csv('profiles.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
# age            59946 non-null int64
# body_type      54650 non-null object
# diet           35551 non-null object
# drinks         56961 non-null object
# drugs          45866 non-null object
# education      53318 non-null object
# essay0         54461 non-null object
# essay1         52375 non-null object
# essay2         50308 non-null object
# essay3         48470 non-null object
# essay4         49409 non-null object
# essay5         49099 non-null object
# essay6         46175 non-null object
# essay7         47496 non-null object
# essay8         40732 non-null object
# essay9         47344 non-null object
# ethnicity      54266 non-null object
# height         59943 non-null float64
# income         59946 non-null int64
# job            51748 non-null object
# last_online    59946 non-null object
# location       59946 non-null object
# ...

# %%
df.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
# ...

# %% [markdown]
# ## The Graphs

# %% [markdown]
# Firstly, I wanted to show a simple plot of value counts for the 'sex' variable:

# %%
ax = sns.countplot(x="sex", data=df)

# %% [markdown]
# Graph of drug use as a function of sex:

# %%
ax = sns.countplot(x="drugs",hue="sex", data=df)

# %% [markdown]
# Maybe a graph of percentage could be more appropriate to draw conclusions from this plot about the difference between men and women.

# %% [markdown]
# I wanted to analyze if there is a connection between smoke and education or age.

# %%
edusmoke = df.groupby(by=['smokes','education']).count()['sex'].unstack()
edusmoke.head()
# Out:
# education       college/university  dropped out of college/university  \
# smokes
# no                           523.0                              600.0
# sometimes                     55.0                              111.0
# trying to quit                29.0                               59.0
# when drinking                 51.0                               79.0
# yes                           35.0                              107.0
#
# education       dropped out of high school  dropped out of law school  \
# smokes
# no                                    39.0                       11.0
# sometimes                             11.0                        1.0
# trying to quit                         9.0                        1.0
# when drinking                         12.0                        1.0
# yes                                   29.0                        2.0
#
# education       dropped out of masters program  dropped out of med school  \
# smokes
# ...

# %% [markdown]
# When I plottes the heatmap of smokes vs education,  I found out that there are windows in this information and it's not the most appropriate graph to display this. The windows are not necessarily missing information

# %%
plt.figure(figsize=(12,6))
sns.heatmap(edusmoke,cmap='viridis')

# %% [markdown]
# We can see that most of the people who graduated from college/university aren't smoking. Or that most of the people who not smoking are graduated from university. (The yellow area).

# %% [markdown]
# The heatmap plot below of smokes vs age, also has missing information. We can understand some intresting things from this plot:
# 1. There is a profile of a 109 year old man. This profile is probably fabricated
# 2. Most of the people in the data aren't smoking
# 3. Most of the users aged 24 to 29
# 4. Most of the young users aren't smoking.

# %%
agesmoke = df.groupby(by=['smokes','age']).count()['sex'].unstack()
agesmoke.head()
plt.figure(figsize=(12,6))
sns.heatmap(agesmoke,cmap='viridis')

# %% [markdown]
# This is another plot of smoking information. Here you can see better that most users don't smoke.
# In order to correctly see the differences between men and women, it was necessary to present the data in percentages, but at this time I could not realize it

# %%
ax = sns.countplot(x="smokes",hue="sex", data=df)

# %%
df['last_online'][5]
# Out:
# '2012-06-29-19-18'

# %% [markdown]
# In the graphs below I examined the connection between age and body type:

# %%
agediet = df.groupby(by=['body_type','age']).count()['sex'].unstack()
agediet.head()
# Out:
# age              18     19     20     21     22     23     24     25     26   \
# body_type
# a little extra  16.0   32.0   58.0   73.0   86.0  127.0  130.0  127.0  129.0
# athletic        41.0  102.0  159.0  210.0  366.0  486.0  614.0  684.0  781.0
# average         91.0  167.0  245.0  374.0  489.0  625.0  779.0  860.0  875.0
# curvy           44.0   58.0   75.0  122.0  152.0  171.0  226.0  199.0  228.0
# fit             31.0   67.0  122.0  176.0  293.0  430.0  584.0  698.0  749.0
#
# age               27  ...    61    62    63    64    65    66    67    68   \
# body_type             ...
# a little extra  134.0 ...   12.0  14.0  13.0  15.0   8.0  12.0   6.0   6.0
# athletic        798.0 ...   18.0  14.0  12.0  15.0  10.0   9.0   7.0   5.0
# average         819.0 ...   62.0  49.0  47.0  41.0  38.0  34.0  19.0  20.0
# curvy           246.0 ...   13.0  14.0  12.0   4.0  11.0   6.0   4.0   2.0
# fit             753.0 ...   42.0  48.0  28.0  24.0  25.0  24.0  19.0  16.0
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(agediet,cmap='viridis')

# %% [markdown]
# We can see again the 109 aged user. Additionaly we can see that most of the average/fit users are 25-26 years old.
# The graph below is another way to look on this information. The conclusions are the same.
# The pick shows that most of the users are 20-40 yeras old.
# A few users wrote that they are overweight, full figured or jacked

# %%
agediet = df.groupby(by=['age','body_type']).count()['sex'].unstack()
agediet.plot(figsize=(10,10), colormap='nipy_spectral')

# %% [markdown]
# Here is a simple pie chart of the users' sex distribution:

# %%
countsex=df['sex'].value_counts()
countsex.plot.pie(figsize=(5, 5),autopct='%.2f%%')

# %% [markdown]
# A pie plot of the users' status distribution:

# %%
countstatus=df['status'].value_counts()
countstatus.plot.pie(figsize=(10, 10),legend=True,labels=None,autopct='%.2f%%',fontsize=15)

# %% [markdown]
# I tried another way to plot this graph:

# %%
byStatus=df.groupby("status").count()
labels=df['status'].unique()
colors = ['greenyellow','yellow','red','deepskyblue','orange']
plt.figure(figsize=(20,10))
plt.pie(byStatus.sex, labels=None,shadow=True, colors=colors,autopct='%1.1f%%')
plt.rcParams['font.size'] = 12
#plt.legend(labels,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0,fontsize=15)
plt.legend(labels,loc=2,fontsize=15)
plt.axis('equal')
# Out:
# (-1.1075267612950914,
#  1.1003584172045282,
#  -1.1078841170127667,
#  1.1039171135718233)

# %% [markdown]
# A pie plot of the users' orientation distribution:

# %%
byOrient=df.groupby("orientation").count()
byOrient
# Out:
#                age  body_type   diet  drinks  drugs  education  essay0  \
# orientation
# bisexual      2767       2439   1717    2625   2009       2443    2599
# gay           5573       5044   2786    5329   4310       4909    5188
# straight     51606      47167  31048   49007  39547      45966   46674
#
#              essay1  essay2  essay3   ...    last_online  location  offspring  \
# orientation                           ...
# bisexual       2544    2478    2410   ...           2767      2767       1213
# gay            4978    4830    4673   ...           5573      5573       1566
# straight      44853   43000   41387   ...          51606     51606      21606
#
#               pets  religion    sex   sign  smokes  speaks  status
# orientation
# bisexual      2148      2071   2767   2367    2545    2765    2767
# gay           3814      3623   5573   4973    5102    5567    5573
# straight     34063     34026  51606  41550   46787   51564   51606
#
# [3 rows x 30 columns]

# %%
byOrient=df.groupby("orientation").count()
#labels=df['orientation'].unique()
labels=['bisexual','gay','straight']
colors = ['greenyellow','yellow','deepskyblue']
plt.figure(figsize=(20,10))
plt.pie(byOrient.age,labels=labels,shadow=True, colors=colors,autopct='%1.1f%%')
plt.rcParams['font.size'] = 12
#plt.legend(labels,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0,fontsize=15)
plt.legend(labels,loc=2,fontsize=15)
plt.axis('equal')
# Out:
# (-1.1065814104529832,
#  1.1003134004977611,
#  -1.1067563580726212,
#  1.1025289816761767)

# %%
#countstatus=df['status'].value_counts()
#countstatus

# %%
#bySex=df.groupby("sex").count()
#bySex['height']

# %% [markdown]
# I wanted to prove from the data that the average height of women is lower than that of men. I tried several ways and the best I got is the two graphs below:

# %%
grid = sns.FacetGrid(df, row="sex", margin_titles=True)
grid.map(plt.hist, "height", bins=np.linspace(55, 80, 25));

# %%
heights = df.groupby(by=['height','sex']).count()['age'].unstack()
heights=heights.reset_index()

# %%
heights.plot.scatter(x='height',y='f')

# %%
heights.plot.scatter(x='height',y='m')

# %% [markdown]
# We can see that the pick of the female graph is lower than the pick in the male graph.

# %%
sns.kdeplot(df.height[df.sex=='f'], label='women', shade=True)
sns.kdeplot(df.height[df.sex=='m'], label='men', shade=True)
plt.xlabel('heights');
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
lenetn=df.ethnicity.unique()
len(lenetn)
# Out:
# 218

# %%
lenspe=df.speaks.unique()
len(lenspe)
# Out:
# 7648

# %%
lenloc=df.location.unique()
len(lenloc)
# Out:
# 199

# %%
lenrel=df.religion.unique()
len(lenrel)
# Out:
# 46

# %%
lensgn=df.sign.unique()
len(lensgn)
# Out:
# 49

# %%
df['New_sign']=df['sign'].apply(lambda x:x.split()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ec40a2e6cd6f> in <module>()
# ----> 1 df['New_sign']=df['sign'].apply(lambda x:x.split()[0])
#
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:66124)()
#
# <ipython-input-29-ec40a2e6cd6f> in <lambda>(x)
# ----> 1 df['New_sign']=df['sign'].apply(lambda x:x.split()[0])
#
# AttributeError: 'float' object has no attribute 'split'
